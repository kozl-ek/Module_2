# %% [markdown]
# # Project_2.Разведывательный анализ данных

# %% [raw]
# Цели:
# 1)Проведите первичную обработку данных. Так как данных много, стоит написать функции, которые можно применять к столбцам определённого типа.
# 2)Посмотрите на распределение признака для числовых переменных, устраните выбросы.
# 3)Оцените количество уникальных значений для номинативных переменных.
# 4)По необходимости преобразуйте данные
# 5)Проведите корреляционный анализ количественных переменных
# 6)Отберите не коррелирующие переменные.
# 7)Проанализируйте номинативные переменные и устраните те, которые не влияют на предсказываемую величину (в нашем случае — на переменную score).
# 8)Не забудьте сформулировать выводы относительно качества данных и тех переменных, которые вы будете использовать в дальнейшем построении модели.

# %% [raw]
# Описание датасета (переменные, которые содержит датасет):
#
# school — аббревиатура школы, в которой учится ученик
# sex — пол ученика ('F' - женский, 'M' - мужской)
# age — возраст ученика (от 15 до 22)
# address — тип адреса ученика ('U' - городской, 'R' - за городом)
# famsize — размер семьи('LE3' <= 3, 'GT3' >3)
# Pstatus — статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)
# Medu — образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# Fedu — образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)
# Mjob — работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# Fjob — работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)
# reason — причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)
# guardian — опекун ('mother' - мать, 'father' - отец, 'other' - другое)
# traveltime — время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)
# studytime — время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)
# failures — количество внеучебных неудач (n, если 1<=n<3, иначе 4)
# schoolsup — дополнительная образовательная поддержка (yes или no)
# famsup — семейная образовательная поддержка (yes или no)
# paid — дополнительные платные занятия по математике (yes или no)
# activities — дополнительные внеучебные занятия (yes или no)
# nursery — посещал детский сад (yes или no)
# higher — хочет получить высшее образование (yes или no)
# internet — наличие интернета дома (yes или no)
# romantic — в романтических отношениях (yes или no)
# famrel — семейные отношения (от 1 - очень плохо до 5 - очень хорошо)
# freetime — свободное время после школы (от 1 - очень мало до 5 - очень мого)
# goout — проведение времени с друзьями (от 1 - очень мало до 5 - очень много)
# health — текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)
# absences — количество пропущенных занятий
# score — баллы по госэкзамену по математике

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind
import numpy as np


pd.set_option('display.max_rows', 50)  # показывать больше строк
pd.set_option('display.max_columns', 50)  # показывать больше колонок

stud_math = pd.read_csv('stud_math.csv')

# %%
display(stud_math.head(15))

stud_math.columns = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob',
                     'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup',
                     'paid', 'activities', 'nursery', 'studytime_granular', 'higher', 'internet', 'romantic', 'famrel',
                     'freetime', 'goout', 'health', 'absences', 'score']
stud_math.info()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1      GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2      GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3      GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4      GP   F   16       U     GT3       T   3.0   3.0     other     other
# 5      GP   M   16       U     LE3       T   4.0   3.0  services     other
# 6      GP   M   16     NaN     LE3       T   2.0   2.0     other     other
# 7      GP   F   17       U     GT3       A   4.0   4.0     other   teacher
# 8      GP   M   15       U     LE3       A   3.0   2.0  services     other
# 9      GP   M   15       U     NaN     NaN   3.0   4.0     other     other
# 10     GP   F   15       U     GT3       T   4.0   4.0   teacher    health
# 11     GP   F   15       U     GT3     NaN   2.0  40.0  services     other
# 12     GP   M   15       U     LE3       T   4.0   4.0    health  services
# 13     GP   M   15       U     GT3       T   4.0   3.0   teacher     other
# 14     GP   M   15       U     GT3       A   2.0   2.0     other     other
#
#         reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 0       course   mother         2.0        2.0       0.0       yes     no
# 1       course   father         1.0        2.0       0.0        no    yes
# 2        other   mother         1.0        2.0       3.0       yes     no
# 3         home   mother         1.0        3.0       0.0        no    yes
# 4         home   father         1.0        2.0       0.0        no    yes
# 5   reputation   mother         1.0        2.0       0.0        no    yes
# 6         home   mother         1.0        2.0       0.0        no     no
# 7         home   mother         2.0        2.0       0.0       yes    yes
# 8         home   mother         1.0        2.0       0.0        no    yes
# 9         home   mother         1.0        2.0       0.0        no    yes
# 10  reputation   mother         1.0        2.0       0.0        no    yes
# 11  reputation   father         3.0        3.0       0.0        no    yes
# 12      course   father         1.0        1.0       0.0        no    yes
# 13      course   mother         2.0        2.0       0.0        no    yes
# 14        home    other         1.0        3.0       0.0        no    yes
#
#    paid activities nursery  studytime, granular higher internet romantic  \
# 0    no         no     yes                 -6.0    yes      NaN       no
# 1    no         no      no                 -6.0    yes      yes       no
# 2   NaN         no     yes                 -6.0    yes      yes      NaN
# 3   yes        yes     yes                 -9.0    yes      yes      yes
# 4   yes         no     yes                 -6.0    yes       no       no
# 5   yes        yes     yes                 -6.0    yes      yes       no
# 6    no         no     yes                 -6.0    yes      yes       no
# 7    no         no     yes                 -6.0    yes       no       no
# 8   yes         no     yes                 -6.0    yes      yes       no
# 9   yes        yes     yes                 -6.0    yes      yes       no
# 10  yes         no     yes                 -6.0    yes      yes       no
# 11   no        yes     yes                 -9.0    yes      yes       no
# 12  yes        yes     yes                 -3.0    yes      NaN       no
# 13  yes         no     yes                 -6.0    yes      yes      NaN
# 14   no         no     yes                 -9.0    yes      yes      yes
#
#     famrel  freetime  goout  health  absences  score
# 0      4.0       3.0    4.0     3.0       6.0   30.0
# 1      5.0       3.0    3.0     3.0       4.0   30.0
# 2      4.0       3.0    2.0     3.0      10.0   50.0
# 3      3.0       2.0    2.0     5.0       2.0   75.0
# 4      4.0       3.0    2.0     5.0       4.0   50.0
# 5      5.0       4.0    2.0     5.0      10.0   75.0
# 6      4.0       4.0    4.0     3.0       0.0   55.0
# 7      4.0       1.0    4.0     1.0       6.0   30.0
# 8      NaN       2.0    2.0     1.0       0.0   95.0
# 9      5.0       5.0    1.0     5.0       0.0   75.0
# 10     3.0       3.0    3.0     2.0       0.0   45.0
# 11     5.0       2.0    2.0     4.0       4.0   60.0
# 12     NaN       3.0    3.0     5.0       2.0   70.0
# 13     5.0       4.0    3.0     3.0       2.0   55.0
# 14     4.0       5.0    2.0     3.0       0.0   80.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   school              395 non-null    object
#  1   sex                 395 non-null    object
#  2   age                 395 non-null    int64
#  3   address             378 non-null    object
#  4   famsize             368 non-null    object
#  5   Pstatus             350 non-null    object
#  6   Medu                392 non-null    float64
#  7   Fedu                371 non-null    float64
#  8   Mjob                376 non-null    object
#  9   Fjob                359 non-null    object
#  10  reason              378 non-null    object
#  11  guardian            364 non-null    object
#  12  traveltime          367 non-null    float64
#  13  studytime           388 non-null    float64
#  14  failures            373 non-null    float64
#  15  schoolsup           386 non-null    object
#  16  famsup              356 non-null    object
#  17  paid                355 non-null    object
#  18  activities          381 non-null    object
#  19  nursery             379 non-null    object
#  20  studytime_granular  388 non-null    float64
#  21  higher              375 non-null    object
#  22  internet            361 non-null    object
#  23  romantic            364 non-null    object
#  24  famrel              368 non-null    float64
#  25  freetime            384 non-null    float64
#  26  goout               387 non-null    float64
#  27  health              380 non-null    float64
#  28  absences            383 non-null    float64
#  29  score               389 non-null    float64
# dtypes: float64(12), int64(1), object(17)
# memory usage: 92.7+ KB

# %% [markdown]
# # Итого:
#     Строковых столбцов:17
#     Числовых столбцов:13

# %%
# Functions
def get_boxplot(column):
    fig, ax = plt.subplots(figsize=(5, 5))
    sns.boxplot(x=column, y='score',
                data=zeromen,
                ax=ax)
    plt.xticks()
    ax.set_title('Boxplot for ' + column)
    plt.show()


def get_boxplot2(column):
    fig, ax = plt.subplots(figsize=(14, 4))
    sns.boxplot(x=column,
                y='score',
                data=stud_math.loc[stud_math.loc[:, column].isin(
                    stud_math.loc[:, column].value_counts().index[:10])],
                ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()


def IQR(column):
    median = stud_math[column].median()
    IQR = stud_math[column].quantile(0.75) - stud_math[column].quantile(0.25)
    perc25 = stud_math[column].quantile(0.25)
    perc75 = stud_math[column].quantile(0.75)
    print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75),
          "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
    sns.boxplot(x=column, data=stud_math)
    stud_math[column].describe()


def get_stat_dif(column):
    cols = stud_math.loc[:, column].value_counts().index[:]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(stud_math.loc[stud_math.loc[:, column] == comb[0], 'score'],
                     stud_math.loc[stud_math.loc[:, column] == comb[1], 'score']).pvalue \
                <= 0.05/len(combinations_all):
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
sns.heatmap(stud_math.corr())

# %% [raw]
# Заметна прямая связь и отрицательная корреляция между studytime и studytime_granular. Судя по всему, чем больше времени на учёбу помимо школы в неделю, тем меньше studytime_granular. Также, это параметр мало связан с параметром свободного времени после школы. Я предполагаю, что это параметр обозначает среднее кол-во часов в неделю, которые отнимают внекласные занятия.
# В любом случае, считаю нужным его удалить, чтобы уменьшить кол-во данных.

# %%
stud_math = stud_math.drop(['studytime_granular'], axis=1)

# %%
# проверим данные на наличие пустых элементов, а затем пройдемся по каждому столбику
stud_math.isnull().sum()
# Out:
# school         0
# sex            0
# age            0
# address       17
# famsize       27
# Pstatus       45
# Medu           3
# Fedu          24
# Mjob          19
# Fjob          36
# reason        17
# guardian      31
# traveltime    28
# studytime      7
# failures      22
# schoolsup      9
# famsup        39
# paid          40
# activities    14
# nursery       16
# higher        20
# internet      34
# romantic      31
# famrel        27
# freetime      11
# goout          8
# health        15
# absences      12
# score          6
# dtype: int64

# %%
# рассмотрим сначала все колонки с числовыми данными, потому что их меньше
stud_math_numbers = pd.DataFrame(stud_math.select_dtypes(include='number'))
fig, axes = plt.subplots(4, 3, figsize=(15, 12))
i = 0
y = 0
for col in stud_math_numbers.columns:
    axes[i][y].plot(stud_math_numbers[col])
    axes[i][y].set_title(col)
    y += 1
    if y == 3:
        y = 0
        i += 1

# %%
# На графиках заметны выбросы на большем числе графиков, рассмотрим каждый по отдельности
IQR('age')
# Out:
# 25-й перцентиль: 16.0, 75-й перцентиль: 18.0, IQR: 2.0,  Границы выбросов: [13.0, 21.0].

# %%
# На боксплоте снова наблюдается выброс, в датафрейм попалу ученик в возрасте 22 года.
stud_math = stud_math.loc[stud_math.age <= 21]

# %%
# Обрабатываем колонку Medu
IQR('Medu')
# Выбросы отсутствуют, есть три пропуска, проверим их
# Out:
# 25-й перцентиль: 2.0, 75-й перцентиль: 4.0, IQR: 2.0,  Границы выбросов: [-1.0, 7.0].

# %%
stud_math[(stud_math.Medu.isnull() == True)]
# Судя по данным, мама 193 работает на гос.службе, для этого нужно высшее образование, добавим ей его
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 92      GP   F   16     NaN     LE3       T   NaN   1.0     other     other
# 193     GP   M   16       R     GT3     NaN   NaN   3.0  services  services
# 239     GP   M   18       U     GT3     NaN   NaN   2.0     other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 92         home   father         1.0        2.0       0.0       yes    yes
# 193  reputation   mother         1.0        1.0       0.0        no    yes
# 239  reputation   father         1.0        2.0       1.0        no     no
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 92    no         no     yes    yes       no       no     3.0       3.0    NaN
# 193   no        yes     yes    yes      yes       no     4.0       3.0    2.0
# 239   no         no     yes     no      NaN      NaN     5.0       5.0    4.0
#
#      health  absences  score
# 92      2.0       4.0   30.0
# 193     5.0       8.0   50.0
# 239     2.0       0.0    0.0

# %%
stud_math.loc[(stud_math.Medu.isnull() == True) & (
    stud_math.Mjob == 'services'), 'Medu'] = 4

# %%
# Обрабатываем колонку Fedu, предположительно, она имеет выброс
IQR('Fedu')
# Out:
# 25-й перцентиль: 2.0, 75-й перцентиль: 3.0, IQR: 1.0,  Границы выбросов: [0.5, 4.5].

# %%
# Вероятно, данные содержат ошибку вместо 40, скорее всего должна быть 4, исправляем ошибку
stud_math.loc[(stud_math.Fedu == 40), 'Fedu'] = 4

# %%
stud_math[(stud_math.Fedu.isnull() == True)]
# наблюдается очень много отцов, которые работают на гос.службе, учителями и в сфере здравоохранения
# у всех учителей точно должно быть высшее образование
# со сферой здравоохранения не все так просто, он может быть мед.братом, может быть врачом.Таких значений 2, не будем заменять.
# гос.служба предполагает высшее образование
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 21      GP   M   15       U     GT3       T   4.0   NaN    health    health
# 42      GP   M   15       U     GT3       T   4.0   NaN  services   teacher
# 46      GP   F   16       U     LE3       A   3.0   NaN     other  services
# 57      GP   M   15       U     GT3       T   4.0   NaN   teacher    health
# 58      GP   M   15       U     LE3       T   1.0   NaN     other   at_home
# 67      GP   F   16       U     GT3     NaN   3.0   NaN  services     other
# 137     GP   F   16       U     GT3       A   3.0   NaN     other     other
# 142     GP   F   15       U     GT3       T   4.0   NaN   teacher  services
# 159     GP   M   16     NaN     GT3       T   3.0   NaN     other  services
# 161     GP   M   15       R     GT3       T   3.0   NaN     other       NaN
# 180     GP   M   16       U     GT3       T   4.0   NaN   teacher     other
# 195     GP   F   17       U     NaN       T   2.0   NaN  services  services
# 232     GP   M   17       U     GT3       T   4.0   NaN   teacher   teacher
# 236     GP   M   17       U     LE3       T   2.0   NaN     other     other
# 259     GP   F   17       U     LE3       T   2.0   NaN  services  services
# 280     GP   M   17       U     NaN       A   4.0   NaN  services     other
# 281     GP   M   17       U     LE3       A   3.0   NaN   teacher  services
# 286     GP   F   18       U     GT3       T   2.0   NaN   at_home   at_home
# 287     GP   F   17       U     GT3       T   1.0   NaN  services   teacher
# 290     GP   M   18       U     GT3       T   4.0   NaN   teacher     other
# 310     GP   F   19       U     LE3       T   1.0   NaN  services  services
# 328     GP   F   17       U     GT3       T   4.0   NaN   teacher  services
# 349     MS   M   18       R     GT3       T   3.0   NaN     other     other
# 374     MS   F   18       R     LE3       T   4.0   NaN     other       NaN
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 21        other   father         1.0        1.0       NaN        no    yes
# 42       course   father         1.0        2.0       0.0        no    yes
# 46         home   mother         1.0        2.0       0.0        no    yes
# 57   reputation   mother         1.0        2.0       0.0        no    yes
# 58         home   father         1.0        2.0       0.0       yes    yes
# 67       course   mother         1.0        4.0       0.0       yes    yes
# 137         NaN    other         NaN        1.0       2.0        no    yes
# 142      course   mother         NaN        3.0       0.0        no    yes
# 159      course   father         1.0        2.0       1.0        no    yes
# 161      course   mother         2.0        2.0       2.0       yes    yes
# 180        home   mother         1.0        2.0       0.0        no    NaN
# 195      course   father         1.0        2.0       0.0        no    NaN
# 232  reputation   mother         1.0        2.0       0.0       yes    NaN
# 236        home   father         1.0        2.0       NaN        no     no
# 259      course   father         1.0        4.0       0.0        no     no
# 280        home   mother         2.0        1.0       NaN        no     no
# 281        home   mother         1.0        1.0       1.0        no     no
# 286       other   mother         1.0        3.0       0.0        no    yes
# 287  reputation   mother         1.0        3.0       0.0        no    yes
# 290        home   mother         1.0        2.0       0.0        no    yes
# 310        home    other         NaN        2.0       1.0        no     no
# 328      course   mother         1.0        3.0       0.0        no    NaN
# 349      course      NaN         2.0        1.0       1.0        no    yes
# 374  reputation   mother         2.0        3.0       0.0        no     no
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 21   NaN         no     yes    yes      yes       no     5.0       4.0    2.0
# 42    no        yes     yes    yes      yes       no     4.0       3.0    3.0
# 46    no         no     yes    yes      yes       no     2.0       3.0    5.0
# 57   NaN        yes     yes    yes       no       no     3.0       2.0    2.0
# 58    no        yes     yes    yes      yes       no     4.0       3.0    2.0
# 67   yes         no     yes    yes      yes      NaN     4.0       3.0    3.0
# 137   no        yes      no    yes      yes      yes     4.0       3.0    2.0
# 142  yes        yes     yes    NaN      yes       no     4.0       2.0    2.0
# 159  yes         no     yes    yes      yes      yes     4.0       5.0    5.0
# 161   no         no     yes    yes      yes      yes     4.0       4.0    4.0
# 180  yes        yes     yes    yes      yes       no     3.0       4.0    3.0
# 195   no        yes     yes    yes      yes      yes     NaN       3.0    2.0
# 232   no        yes     yes    yes      yes      yes     4.0       5.0    5.0
# 236  NaN        yes      no    yes      yes      yes     4.0       4.0    2.0
# 259  yes        yes     yes    yes      NaN      yes     3.0       4.0    1.0
# 280  yes        yes     yes    yes      yes      NaN     4.0       NaN    4.0
# 281   no         no     yes    NaN      yes       no     4.0       4.0    4.0
# 286  yes         no     yes    yes      yes       no     4.0       3.0    3.0
# 287  yes         no     yes    yes      yes       no     4.0       3.0    3.0
# 290  yes        yes     yes    yes      yes      NaN     NaN       NaN    2.0
# 310   no        yes      no    yes       no      yes     4.0       2.0    4.0
# 328  yes        yes     yes    yes      yes       no     5.0       4.0    4.0
# 349   no         no      no    yes      yes       no     NaN       5.0    5.0
# 374   no         no     yes    yes      yes       no     5.0       4.0    4.0
#
#      health  absences  score
# 21      5.0       0.0   75.0
# 42      5.0       2.0   90.0
# 46      3.0      12.0   55.0
# 57      5.0       4.0   75.0
# 58      5.0       2.0   45.0
# 67      5.0       4.0   30.0
# 137     5.0       0.0    0.0
# 142     5.0       2.0   55.0
# 159     5.0       4.0   60.0
# 161     3.0       6.0   35.0
# 180     3.0      10.0   40.0
# 195     5.0       0.0   75.0
# 232     2.0      14.0   45.0
# 236     NaN       4.0   65.0
# 259     NaN       0.0    0.0
# 280     5.0      30.0   40.0
# 281     3.0      19.0   50.0
# 286     2.0       5.0   95.0
# 287     3.0       6.0   60.0
# 290     5.0      11.0   55.0
# 310     3.0       0.0    0.0
# 328     4.0       7.0   45.0
# 349     5.0      10.0   65.0
# 374     1.0       0.0   95.0

# %%
stud_math.loc[(stud_math.Fedu.isnull() == True) & (
    stud_math.Fjob == 'services'), 'Fedu'] = 4
stud_math.loc[(stud_math.Fedu.isnull() == True) & (
    stud_math.Fjob == 'teacher'), 'Fedu'] = 4

# %%
# Обрабатываем колонку Traveltime
IQR('traveltime')
# имеются выбросы, и 28 пустых значений, посмотрим на них
# Out:
# 25-й перцентиль: 1.0, 75-й перцентиль: 2.0, IQR: 1.0,  Границы выбросов: [-0.5, 3.5].

# %%
stud_math[(stud_math.traveltime.isnull() == True)]
# однозначно, если при выборе школы в приоритете было близкое расположение, то добираться до нее не больше 15 минут.
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 26      GP   M   15       U     GT3       T   2.0   2.0     other       NaN
# 30      GP   M   15       U     GT3       T   4.0   4.0    health  services
# 35      GP   F   15       U     GT3       T   2.0   3.0     other     other
# 37      GP   M   16       R     GT3       A   4.0   4.0     other   teacher
# 59      GP   F   16       U     GT3       T   4.0   2.0       NaN       NaN
# 68      GP   F   15       R     LE3       T   2.0   2.0    health       NaN
# 70      GP   M   16       U     GT3       T   3.0   1.0     other     other
# 104     GP   M   15       U     GT3       A   3.0   4.0       NaN     other
# 112     GP   F   16       U     GT3     NaN   2.0   2.0   at_home     other
# 132     GP   F   17       U     LE3       T   2.0   2.0     other     other
# 134     GP   M   15       R     GT3       T   3.0   4.0   at_home   teacher
# 137     GP   F   16       U     GT3       A   3.0   NaN     other     other
# 142     GP   F   15       U     GT3       T   4.0   4.0   teacher  services
# 147     GP   F   15       U     GT3     NaN   1.0   2.0   at_home     other
# 157     GP   F   18       R     GT3       T   1.0   1.0   at_home     other
# 160     GP   M   17       R     LE3       T   2.0   1.0   at_home       NaN
# 182     GP   F   17       U     GT3     NaN   2.0   4.0  services       NaN
# 226     GP   F   17       U     GT3       T   3.0   2.0     other     other
# 234     GP   M   16       U     LE3     NaN   1.0   1.0     other     other
# 241     GP   M   17     NaN     LE3       A   4.0   4.0   teacher     other
# 261     GP   M   18       U     GT3       T   4.0   3.0   teacher     other
# 268     GP   M   18       U     NaN     NaN   4.0   2.0       NaN     other
# 310     GP   F   19       U     LE3       T   1.0   4.0  services  services
# 348     GP   F   17     NaN     GT3       T   4.0   3.0    health     other
# 372     MS   F   17     NaN     GT3       T   2.0   2.0     other   at_home
# 384     MS   M   18       R     GT3       T   4.0   2.0     other       NaN
# 385     MS   F   18       R     GT3       T   2.0   2.0   at_home     other
# 389     MS   F   18       U     GT3       T   1.0   1.0     other     other
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 26         home   mother         NaN        1.0       0.0        no    yes
# 30         home   mother         NaN        2.0       0.0        no    yes
# 35        other   father         NaN        1.0       0.0       NaN    yes
# 37   reputation   mother         NaN        3.0       0.0        no    yes
# 59       course   mother         NaN        2.0       0.0        no    NaN
# 68   reputation   mother         NaN        2.0       NaN       yes    yes
# 70   reputation   father         NaN        4.0       0.0        no    yes
# 104      course   mother         NaN        2.0       0.0        no    yes
# 112         NaN   mother         NaN        NaN       1.0       yes     no
# 132      course   father         NaN        1.0       0.0        no    yes
# 134      course   mother         NaN        2.0       0.0        no    yes
# 137         NaN    other         NaN        1.0       2.0        no    yes
# 142      course   mother         NaN        3.0       0.0        no    yes
# 147      course   mother         NaN        2.0       0.0        no    yes
# 157      course   mother         NaN        1.0       3.0        no    yes
# 160      course   mother         NaN        1.0       2.0        no     no
# 182  reputation   father         NaN        2.0       0.0        no    yes
# 226      course   mother         NaN        2.0       0.0        no     no
# 234        home   mother         NaN        2.0       0.0        no    NaN
# 241      course   mother         NaN        2.0       0.0        no    yes
# 261      course   mother         NaN        2.0       NaN        no    yes
# 268  reputation   father         NaN        2.0       0.0        no    NaN
# 310        home    other         NaN        2.0       1.0        no     no
# 348  reputation   mother         NaN        3.0       0.0        no    yes
# 372        home   mother         NaN        3.0       0.0        no     no
# 384        home   father         NaN        1.0       1.0        no     no
# 385       other      NaN         NaN        3.0       0.0        no     no
# 389      course   mother         NaN        2.0       1.0        no     no
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 26   NaN         no     yes    yes      yes      NaN     4.0       2.0    2.0
# 30   yes         no      no    yes      yes       no     5.0       4.0    2.0
# 35    no        yes     yes    yes       no       no     3.0       5.0    1.0
# 37    no        yes     yes    yes      yes      yes     2.0       4.0    3.0
# 59    no         no     yes    yes      yes       no     4.0       2.0    3.0
# 68   NaN         no     yes    yes      yes       no     4.0       1.0    3.0
# 70   yes         no     yes    yes      yes       no     4.0       3.0    2.0
# 104  NaN        yes     yes    yes      yes       no     5.0       4.0    4.0
# 112   no        yes     yes    yes      yes      NaN     3.0       1.0    2.0
# 132   no         no     yes    yes      NaN      yes     3.0       4.0    4.0
# 134   no         no     yes    yes       no      yes     5.0       3.0    3.0
# 137   no        yes      no    yes      yes      yes     4.0       3.0    2.0
# 142  yes        yes     yes    NaN      yes       no     4.0       2.0    2.0
# 147  yes         no      no    yes      yes      NaN     4.0       3.0    2.0
# 157   no        yes      no    yes       no       no     5.0       2.0    5.0
# 160   no        NaN     yes     no      yes      yes     NaN       3.0    2.0
# 182   no        yes     yes    yes       no       no     5.0       4.0    2.0
# 226   no        yes      no    yes      yes       no     5.0       3.0    4.0
# 234  yes         no     yes    yes      yes       no     3.0       4.0    2.0
# 241  yes         no     yes    yes      yes       no     3.0       3.0    NaN
# 261  yes         no      no    yes      yes      NaN     4.0       3.0    2.0
# 268  yes        yes     yes    yes      yes      yes     5.0       4.0    5.0
# 310   no        yes      no    yes       no      yes     4.0       2.0    4.0
# 348  yes        yes     yes    yes      yes      yes     NaN       4.0    3.0
# 372   no        yes     yes    yes       no      NaN     3.0       4.0    3.0
# 384  NaN         no     yes    yes      NaN       no     5.0       4.0    3.0
# 385  yes         no     yes    yes      NaN       no     5.0       3.0    3.0
# 389   no        yes     yes    yes      NaN       no     1.0       1.0    1.0
#
#      health  absences  score
# 26      5.0       2.0   55.0
# 30      NaN       0.0   60.0
# 35      5.0       0.0   30.0
# 37      5.0       7.0   75.0
# 59      5.0       2.0   80.0
# 68      4.0       2.0   40.0
# 70      5.0       0.0   75.0
# 104     1.0       0.0   90.0
# 112     5.0       6.0   65.0
# 132     5.0      12.0   60.0
# 134     5.0       0.0    0.0
# 137     5.0       0.0    0.0
# 142     5.0       2.0   55.0
# 147     5.0       2.0   55.0
# 157     4.0       6.0   50.0
# 160     5.0       0.0    0.0
# 182     5.0       0.0   85.0
# 226     3.0      10.0   75.0
# 234     5.0      18.0   30.0
# 241     4.0       2.0   60.0
# 261     3.0       2.0   40.0
# 268     5.0      10.0   50.0
# 310     3.0       0.0    0.0
# 348     4.0       0.0   75.0
# 372     3.0       8.0   55.0
# 384     3.0      14.0   25.0
# 385     4.0       2.0   50.0
# 389     5.0       0.0    0.0

# %%
stud_math.loc[(stud_math.traveltime.isnull() == True) &
              (stud_math.reason == 'home'), 'traveltime'] = 1
# проверим, как далеко сельская местность от школы
sns.barplot(x='address', y='traveltime', data=stud_math)
# судя по графикам сельская местность не означает, что ребенок тратит больше часа на дорогу до школы, оставляем как есть.

# %%
# Обрабатываем колонку studytime
IQR('studytime')
# имеются выбросы, 7 пропусков, посмотрим на них
# Out:
# 25-й перцентиль: 1.0, 75-й перцентиль: 2.0, IQR: 1.0,  Границы выбросов: [-0.5, 3.5].

# %%
stud_math[(stud_math.studytime.isnull() == True)]
# видно, что большинство учеников берут доп.занятия по метематике, посмотрим, как это связано с параметром studytime
sns.boxplot(x='paid', y='studytime', data=stud_math)

# %%
# судя по всему, занятия по математике длятся от 2-5 часов, заменим пустые значения
stud_math.loc[(stud_math.studytime.isnull() == True) &
              (stud_math.paid == 'yes'), 'studytime'] = 2

# %%
# Обрабатываем колонку failures
stud_math.failures.value_counts()
# большинство учеников не испытывало трудностей с учебой, поэтому неудачи скорее являются выбросами для данной колонки
# В датафрейме 22 пустых значение, посмотрим на них
# Out:
# 0.0    293
# 1.0     49
# 2.0     16
# 3.0     14
# Name: failures, dtype: int64

# %%
stud_math[(stud_math.failures.isnull() == True)]
# можно попытаться связать неудачи с пропусками, но мы не может быть уверены в их кол-ве, поэтому оставляем как есть
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 21      GP   M   15       U     GT3       T   4.0   NaN    health    health
# 48      GP   M   15       U     GT3       T   4.0   2.0   teacher     other
# 54      GP   F   15       U     LE3     NaN   3.0   3.0       NaN     other
# 68      GP   F   15       R     LE3       T   2.0   2.0    health       NaN
# 91      GP   F   15       U     GT3       T   4.0   3.0  services     other
# 107     GP   M   16       U     GT3       T   3.0   3.0  services       NaN
# 108     GP   M   15       R     GT3     NaN   4.0   4.0     other     other
# 114     GP   M   15       R     NaN       T   2.0   1.0    health  services
# 115     GP   M   16       U     GT3       T   4.0   4.0   teacher   teacher
# 125     GP   M   15       U     GT3       T   3.0   4.0  services  services
# 153     GP   M   19       U     GT3     NaN   3.0   2.0  services   at_home
# 158     GP   M   16       R     GT3     NaN   2.0   2.0   at_home     other
# 170     GP   M   16       U     GT3       T   3.0   4.0     other     other
# 171     GP   M   16       U     GT3       T   1.0   0.0     other     other
# 204     GP   F   16       R     GT3       T   2.0   2.0  services  services
# 214     GP   F   17       R     LE3       T   4.0   4.0  services     other
# 236     GP   M   17       U     LE3       T   2.0   NaN     other     other
# 261     GP   M   18       U     GT3       T   4.0   3.0   teacher     other
# 280     GP   M   17       U     NaN       A   4.0   NaN  services     other
# 313     GP   F   19       U     NaN     NaN   3.0   2.0  services     other
# 320     GP   F   17       U     GT3       A   4.0   3.0  services  services
# 344     GP   F   18       U     NaN       T   2.0   3.0   at_home     other
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 21        other   father         1.0        1.0       NaN        no    yes
# 48         home   mother         1.0        2.0       NaN        no    yes
# 54        other   mother         1.0        1.0       NaN        no     no
# 68   reputation   mother         NaN        2.0       NaN       yes    yes
# 91   reputation   mother         1.0        2.0       NaN        no     no
# 107        home   father         1.0        3.0       NaN        no    yes
# 108        home   father         4.0        4.0       NaN        no    yes
# 114  reputation   mother         1.0        2.0       NaN        no     no
# 115      course   father         1.0        2.0       NaN        no    yes
# 125        home   father         1.0        1.0       NaN       yes     no
# 153        home   mother         1.0        1.0       NaN        no    yes
# 158      course   mother         3.0        1.0       NaN        no     no
# 170      course   father         3.0        1.0       NaN        no    yes
# 171  reputation   mother         2.0        2.0       NaN        no    yes
# 204  reputation   mother         2.0        4.0       NaN        no    yes
# 214       other   mother         1.0        1.0       NaN        no    yes
# 236        home   father         1.0        2.0       NaN        no     no
# 261      course   mother         NaN        2.0       NaN        no    yes
# 280        home   mother         2.0        1.0       NaN        no     no
# 313  reputation    other         2.0        2.0       NaN        no    NaN
# 320      course   mother         1.0        2.0       NaN        no    yes
# 344      course      NaN         1.0        3.0       NaN        no    yes
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 21   NaN         no     yes    yes      yes       no     5.0       4.0    2.0
# 48   yes         no     yes    NaN       no       no     4.0       3.0    3.0
# 54   yes        NaN     yes    yes      yes      NaN     5.0       3.0    4.0
# 68   NaN         no     yes    yes      yes       no     4.0       1.0    3.0
# 91   yes        yes     yes    yes      yes       no     4.0       5.0    5.0
# 107   no        yes     yes    yes      yes       no     5.0       3.0    3.0
# 108  yes        yes     yes    yes      yes      yes     1.0       3.0    5.0
# 114   no        yes     yes    yes      yes      yes     5.0       4.0    2.0
# 115   no        yes     yes    yes      NaN       no     5.0       4.0    4.0
# 125   no         no     yes    yes      NaN       no     5.0       5.0    5.0
# 153   no         no     yes     no      yes      yes     4.0       5.0    4.0
# 158   no         no      no    NaN       no       no     4.0       2.0    2.0
# 170   no        yes      no    NaN      yes       no     3.0       4.0    5.0
# 171  yes        yes     yes    NaN      yes      yes     4.0       3.0    2.0
# 204  yes        yes      no    yes      yes      NaN     5.0       3.0    5.0
# 214  NaN         no     yes    yes       no       no     5.0       2.0    1.0
# 236  NaN        yes      no    yes      yes      yes     4.0       4.0    2.0
# 261  yes         no      no    yes      yes      NaN     4.0       3.0    2.0
# 280  yes        yes     yes    yes      yes      NaN     4.0       NaN    4.0
# 313  NaN         no      no    yes      yes      yes     4.0       2.0    2.0
# 320  yes         no     yes    NaN      yes      yes     5.0       2.0    2.0
# 344   no         no     yes    yes      yes       no     4.0       3.0    3.0
#
#      health  absences  score
# 21      5.0       0.0   75.0
# 48      5.0       2.0   70.0
# 54      1.0       6.0   65.0
# 68      4.0       2.0   40.0
# 91      1.0       4.0   90.0
# 107     5.0       2.0   90.0
# 108     1.0       6.0   65.0
# 114     5.0       8.0   45.0
# 115     5.0       2.0   80.0
# 125     5.0       0.0   60.0
# 153     NaN       0.0    0.0
# 158     3.0       2.0   75.0
# 170     2.0       0.0    0.0
# 171     3.0       2.0   80.0
# 204     5.0       6.0   55.0
# 214     3.0      12.0   50.0
# 236     NaN       4.0   65.0
# 261     3.0       2.0   40.0
# 280     5.0      30.0   40.0
# 313     1.0      22.0   55.0
# 320     5.0      23.0   65.0
# 344     3.0       4.0   50.0

# %%
# Обрабатываем колонку famrel
IQR('famrel')
stud_math.famrel.value_counts()
# Out:
# 25-й перцентиль: 4.0, 75-й перцентиль: 5.0, IQR: 1.0,  Границы выбросов: [2.5, 6.5].
#  4.0    182
#  5.0     98
#  3.0     62
#  2.0     17
#  1.0      7
# -1.0      1
# Name: famrel, dtype: int64

# %%
# очевидная ошибка в данных. Критерий может иметь оценку от 1 до 5 баллов, в данном случае есть отрицательная величина
stud_math.loc[stud_math.famrel == -1, 'famrel'] = 1
# у большинства учеников хорошие отношения с родителями, обратное скорее является исключением

# %%
# Обрабатываем колонку freetime
IQR('freetime')
stud_math.famrel.value_counts()
# большинство учеников имеют достаточно свободного времени
# Out:
# 25-й перцентиль: 3.0, 75-й перцентиль: 4.0, IQR: 1.0,  Границы выбросов: [1.5, 5.5].
# 4.0    182
# 5.0     98
# 3.0     62
# 2.0     17
# 1.0      8
# Name: famrel, dtype: int64

# %%
# посмотрим на пустые значение
stud_math[(stud_math.freetime.isnull() == True)]
#  посмотрим, зависит ли свободное время от романтических отношений
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 32      GP   M   15       R     NaN       T   4.0   3.0   teacher   at_home
# 74      GP   F   16       U     GT3       T   3.0   3.0     other  services
# 131     GP   F   15       U     GT3     NaN   1.0   1.0   at_home     other
# 201     GP   F   16       U     GT3       T   2.0   3.0     other     other
# 280     GP   M   17       U     NaN       A   4.0   NaN  services     other
# 283     GP   F   18       U     GT3       T   1.0   1.0     other     other
# 290     GP   M   18       U     GT3       T   4.0   NaN   teacher     other
# 291     GP   F   17       U     GT3       T   4.0   3.0       NaN  services
# 311     GP   F   19       U     GT3       T   2.0   1.0   at_home     other
# 314     GP   F   19       U     GT3       T   1.0   1.0   at_home    health
# 338     GP   F   18       U     LE3       T   3.0   3.0  services  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 32       course   mother         1.0        2.0       0.0        no    yes
# 74         home   mother         1.0        2.0       0.0       yes    yes
# 131      course   mother         3.0        1.0       0.0        no    yes
# 201  reputation   mother         1.0        2.0       0.0       yes    yes
# 280        home   mother         2.0        1.0       NaN        no     no
# 283        home   mother         2.0        2.0       0.0       yes    NaN
# 290        home   mother         1.0        2.0       0.0        no    yes
# 291  reputation      NaN         1.0        3.0       0.0        no    yes
# 311       other    other         3.0        2.0       0.0        no    yes
# 314        home    other         1.0        NaN       2.0        no     no
# 338        home   mother         1.0        4.0       0.0        no    yes
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 32    no        yes     NaN    yes      yes      yes     4.0       NaN    2.0
# 74   yes        yes     yes    yes      yes       no     4.0       NaN    3.0
# 131   no        yes      no    yes      yes      yes     4.0       NaN    3.0
# 201  NaN        yes     yes    yes       no       no     4.0       NaN    3.0
# 280  yes        yes     yes    yes      yes      NaN     4.0       NaN    4.0
# 283   no        yes     yes    yes      yes       no     5.0       NaN    4.0
# 290  yes        yes     yes    yes      yes      NaN     NaN       NaN    2.0
# 291  yes         no     yes    yes      yes       no     4.0       NaN    2.0
# 311   no         no     yes     no      yes      yes     3.0       NaN    1.0
# 314   no         no      no    yes      yes      yes     4.0       NaN    2.0
# 338   no         no     yes    yes      yes       no     5.0       NaN    3.0
#
#      health  absences  score
# 32      5.0       0.0   80.0
# 74      5.0      54.0   55.0
# 131     4.0       0.0    0.0
# 201     4.0       6.0    NaN
# 280     5.0      30.0   40.0
# 283     4.0       4.0    NaN
# 290     5.0      11.0   55.0
# 291     3.0       0.0   75.0
# 311     2.0      20.0   65.0
# 314     3.0      14.0   65.0
# 338     1.0       7.0   85.0

# %%
sns.boxplot(x='romantic', y='freetime', data=stud_math)
# судя по всему нет, жаль)

# %%
# проверим есть ли связь с друзьями
sns.boxplot(x='goout', y='freetime', data=stud_math)
# заметна корреляция, чем больше свободного времени, тем больше ученик проводит времени с друзьями,заменим на средние значения

# %%
stud_math.loc[(stud_math.freetime.isnull() == True) &
              (stud_math.goout == 1), 'freetime'] = 3
stud_math.loc[(stud_math.freetime.isnull() == True) &
              (stud_math.goout == 2), 'freetime'] = 3
stud_math.loc[(stud_math.freetime.isnull() == True) &
              (stud_math.goout == 3), 'freetime'] = 3
stud_math.loc[(stud_math.freetime.isnull() == True) &
              (stud_math.goout == 4), 'freetime'] = 3
stud_math.loc[(stud_math.freetime.isnull() == True) &
              (stud_math.goout == 5), 'freetime'] = 4

# %%
# Обрабатываем колонку goout
IQR('goout')
stud_math.goout.value_counts()
# выбросов нет, пропусков 8, заменим так же, как и в предыдущем случае
# Out:
# 25-й перцентиль: 2.0, 75-й перцентиль: 4.0, IQR: 2.0,  Границы выбросов: [-1.0, 7.0].
# 3.0    127
# 2.0    101
# 4.0     84
# 5.0     51
# 1.0     23
# Name: goout, dtype: int64

# %%
sns.boxplot(x='freetime', y='goout', data=stud_math)

# %%
stud_math.loc[(stud_math.goout.isnull() == True) &
              (stud_math.freetime == 1), 'goout'] = 2
stud_math.loc[(stud_math.goout.isnull() == True) &
              (stud_math.freetime == 2), 'goout'] = 2
stud_math.loc[(stud_math.goout.isnull() == True) &
              (stud_math.freetime == 3), 'goout'] = 3
stud_math.loc[(stud_math.goout.isnull() == True) &
              (stud_math.freetime == 4), 'goout'] = 3.5
stud_math.loc[(stud_math.goout.isnull() == True) &
              (stud_math.freetime == 5), 'goout'] = 4

# %%
# Обрабатываем колонку health
IQR('health')
stud_math.health.value_counts()
# выбросов нет, пропусков 15, попробуем заполнить на основании идео и том, что если родители работают в здравоохранении, то здоровье ребенка в порядке
# Out:
# 25-й перцентиль: 3.0, 75-й перцентиль: 5.0, IQR: 2.0,  Границы выбросов: [0.0, 8.0].
# 5.0    138
# 3.0     89
# 4.0     63
# 1.0     46
# 2.0     43
# Name: health, dtype: int64

# %%
stud_math.loc[(stud_math.health.isnull() == True) &
              (stud_math.Mjob == 'health'), 'health'] = 5
stud_math.loc[(stud_math.health.isnull() == True) &
              (stud_math.Fjob == 'health'), 'health'] = 5
stud_math.health.value_counts()
# Мда, много добавить не удалось)
# Out:
# 5.0    139
# 3.0     89
# 4.0     63
# 1.0     46
# 2.0     43
# Name: health, dtype: int64

# %%
# Обрабатываем колонку absences, предположительно она содержит выбросы
IQR('absences')
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %%
# очевидная ошибка, обнаружены огромные выбросы, отфильтруем данные
stud_math = stud_math.loc[(stud_math.absences >= -12)
                          & (stud_math.absences <= 20)]

# %%
# Рассмотрим целевую переменную score, она имеет 6 пустых значений
stud_math.score.hist(color='green', bins=70)
# Наблюдается большое кол-во результата =0

# %%
zeromen = stud_math[stud_math.score == 0]
fig, axes = plt.subplots(10, 3, figsize=(20, 20))
i = 0
y = 0
for col in zeromen.columns:
    axes[i][y].bar(x=zeromen[col].value_counts().index,
                   height=zeromen[col].value_counts())
    axes[i][y].set_title(col)
    y += 1
    if y == 3:
        y = 0
        i += 1
# По графику о неудачах заметно, что школьники, получившие оценку 0 испытывали сложности с учебой, также часть из них имела проблемы со здоровьем
# возможно 0 получили те, кто просто не пришел

# %%
# есть пропуски, заменим их на среднее, чтобы не портить статистику
stud_math.loc[stud_math.score.isnull() == True,
              'score'] = stud_math.score.mean()

# %%
# Заполним пропуски средним значением, статистика от этого не изменится, но мы избавимся от пропусков
stud_math.score = stud_math.score[stud_math.score != 0]
stud_math.score.hist(color='green', bins=70)

# %% [raw]
# Теперь посмотрим на нечисловые данные

# %%
# рассмотрим сначала все колонки с нечисловые данными,проверяя есть ли пустые значения
stud_math_object = pd.DataFrame(stud_math.select_dtypes(include=[object]))
fig, axes = plt.subplots(6, 3, figsize=(15, 12))
i = 0
y = 0
for col in stud_math_object.columns:
    stud_math_object[col].fillna(value='None', inplace=True)
    axes[i][y].bar(x=stud_math_object[col].value_counts().index,
                   height=stud_math_object[col].value_counts())
    axes[i][y].set_title(col)
    y += 1
    if y == 3:
        y = 0
        i += 1

# %%
# Проверяем каждый в отдельности
# School пропускаем, нет пустых значений, по графику все видно, большинство учеников посещают школу GP
# Sex  тоже пропускаем, нет пустых значений,большинство учащихся-девочки
# Проверяем колонку address
stud_math.loc[:, ['address']].info()
pd.DataFrame(stud_math.address.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   address  350 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#    address
# U      272
# R       78

# %%
# анализ данных показал, что нельзя отталкиваться от параметра timetravel, поэтому оставляем без изменений

# %%
# Проверяем колонку famsize
stud_math.loc[:, ['famsize']].info()
pd.DataFrame(stud_math.famsize.value_counts())
# 27 пропусков, но на основании имеющихся данных ничего не можем сделать
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   famsize  343 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      famsize
# GT3      244
# LE3       99

# %%
# Проверяем колонку Pstatus
stud_math.loc[:, ['Pstatus']].info()
pd.DataFrame(stud_math.Pstatus.value_counts())
# 45 пустых значений, скорее всего если в семье больше 3 человек, то родители живут вместе
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Pstatus  327 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#    Pstatus
# T      295
# A       32

# %%
stud_math.loc[(stud_math.Pstatus.isnull() == True) & (
    stud_math.famsize == 'GT3'), 'Pstatus'] = "T"
pd.DataFrame(stud_math.Pstatus.value_counts())
# Out:
#    Pstatus
# T      320
# A       32

# %%
# Проверяем колонку Mjob
stud_math.loc[:, ['Mjob']].info()
pd.DataFrame(stud_math.Mjob.value_counts())
# в ней 19 пустых значений, но данных на их замену нет, оставляем так
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mjob    349 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#           Mjob
# other      123
# services    87
# at_home     55
# teacher     52
# health      32

# %%
# Проверяем колонку Fjob
stud_math.loc[:, ['Fjob']].info()
pd.DataFrame(stud_math.Mjob.value_counts())
# в ней 36 пустых значений, но данных на их замену нет, оставляем так
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fjob    331 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#           Mjob
# other      123
# services    87
# at_home     55
# teacher     52
# health      32

# %%
# Проверяем колонку reason
stud_math.loc[:, ['reason']].info()
pd.DataFrame(stud_math.reason.value_counts())
# Проверим, сколько учеников живет в 15 минутха ходьбы от школы и заменим пустые значения на home
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   reason  348 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#             reason
# course         129
# reputation      94
# home            94
# other           31

# %%
stud_math.loc[(stud_math.reason.isnull() == True) & (
    stud_math.traveltime == 1), 'reason'] = 'home'
pd.DataFrame(stud_math.reason.value_counts())
# Out:
#             reason
# course         129
# home           107
# reputation      94
# other           31

# %%
# Проверяем колонку guardian
stud_math.loc[:, ['guardian']].info()
pd.DataFrame(stud_math.guardian.value_counts())
# всего 31 пропущенное значение, проверим статус работы родителя, если он работает из дома,то он и есть опекун
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   guardian  335 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#         guardian
# mother       228
# father        83
# other         24

# %%
stud_math.loc[(stud_math.guardian.isnull() == True) & (
    stud_math.Mjob == 'at_home'), 'guardian'] = 'mother'
stud_math.loc[(stud_math.guardian.isnull() == True) & (
    stud_math.Fjob == 'at_home'), 'guardian'] = 'father'
pd.DataFrame(stud_math.guardian.value_counts())
# Out:
#         guardian
# mother       235
# father        83
# other         24

# %%
# Проверяем колонку schoolsup
stud_math.loc[:, ['schoolsup']].info()
pd.DataFrame(stud_math.schoolsup.value_counts())
# есть 9 пустых значений, но нет основательных предположений, чтобы это изменить
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   schoolsup  356 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      schoolsup
# no         309
# yes         47

# %%
# Проверяем колонку famsup
stud_math.loc[:, ['famsup']].info()
pd.DataFrame(stud_math.famsup.value_counts())
# есть 39 пустых значений, но нет основательных предположений, чтобы это изменить
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   famsup  330 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      famsup
# yes     204
# no      126

# %%
# Проверяем колонку paid
stud_math.loc[:, ['paid']].info()
pd.DataFrame(stud_math.paid.value_counts())
# есть 40 пустых значений, но нет основательных предположений, чтобы это изменить
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   paid    327 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      paid
# no    188
# yes   139

# %%
# Проверяем колонку activities
stud_math.loc[:, ['activities']].info()
pd.DataFrame(stud_math.activities.value_counts())
# есть 14 пустых значений, но нет основательных предположений, чтобы это изменить
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   activities  351 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      activities
# yes         184
# no          167

# %%
# Проверяем колонку nursery
stud_math.loc[:, ['nursery']].info()
pd.DataFrame(stud_math.nursery.value_counts())
# есть 16 пустых значений, посмотрим эти значения
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nursery  349 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      nursery
# yes      277
# no        72

# %%
stud_math[stud_math.nursery.isnull() == True]
# скорее всего, если родитель работает из дома, то ребенок в садик не ходил
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 22      GP   M   16       U     LE3       T   4.0   2.0   teacher       NaN
# 32      GP   M   15       R     NaN       T   4.0   3.0   teacher   at_home
# 85      GP   F   15       U     GT3       T   4.0   4.0  services  services
# 88      GP   M   16       U     GT3       T   2.0   2.0       NaN     other
# 152     GP   F   15       R     GT3       T   3.0   3.0  services       NaN
# 212     GP   F   16       U     GT3       A   2.0   2.0     other     other
# 249     GP   M   16       U     GT3       T   0.0   2.0     other     other
# 300     GP   F   18       U     LE3       A   4.0   4.0    health     other
# 332     GP   F   18       U     GT3       T   3.0   3.0  services  services
# 336     GP   F   19       R     GT3       A   3.0   1.0  services       NaN
# 340     GP   F   19       U     GT3       T   2.0   1.0  services  services
# 341     GP   M   18       U     GT3       T   4.0   4.0   teacher       NaN
# 350     MS   M   19     NaN     GT3       T   1.0   1.0     other  services
# 359     MS   F   18     NaN     LE3       T   1.0   1.0   at_home  services
# 365     MS   M   18       R     GT3       T   1.0   3.0   at_home       NaN
# 383     MS   M   19       R     GT3       T   1.0   1.0     other  services
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 22       course   mother         1.0        2.0       0.0        no    NaN
# 32       course   mother         1.0        2.0       0.0        no    yes
# 85   reputation   father         2.0        2.0       2.0        no     no
# 88   reputation   father         2.0        2.0       1.0        no     no
# 152  reputation    other         2.0        3.0       2.0        no    yes
# 212  reputation   mother         1.0        2.0       0.0       yes    yes
# 249       other   mother         1.0        1.0       0.0        no     no
# 300        home   mother         1.0        2.0       0.0        no    yes
# 332        home   mother         1.0        2.0       0.0        no     no
# 336        home    other         1.0        3.0       1.0        no     no
# 340        home    other         1.0        3.0       1.0        no     no
# 341        home   father         1.0        2.0       1.0        no    yes
# 350        home    other         3.0        2.0       3.0        no     no
# 359      course   father         2.0        3.0       0.0        no     no
# 365      course   mother         2.0        2.0       0.0        no    yes
# 383       other   mother         2.0        1.0       1.0        no     no
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 22    no        yes     NaN    yes      yes       no     4.0       5.0    1.0
# 32    no        yes     NaN    yes      yes      yes     4.0       3.0    2.0
# 85   yes         no     NaN    yes      yes      yes     4.0       4.0    4.0
# 88   yes        yes     NaN    yes      yes       no     4.0       4.0    2.0
# 152  yes        yes     NaN    yes      yes      yes     4.0       2.0    1.0
# 212  yes        NaN     NaN    yes      yes       no     3.0       3.0    4.0
# 249  yes         no     NaN    yes      yes       no     4.0       3.0    2.0
# 300   no         no     NaN    yes      yes      yes     4.0       2.0    4.0
# 332   no        yes     NaN    yes      yes       no     5.0       3.0    4.0
# 336  yes         no     NaN    yes       no       no     5.0       4.0    3.0
# 340  yes        yes     NaN    yes      NaN      yes     4.0       3.0    4.0
# 341  NaN        yes     NaN    yes      yes       no     4.0       3.0    3.0
# 350   no         no     NaN    yes      yes       no     5.0       4.0    4.0
# 359   no         no     NaN    yes      yes       no     5.0       3.0    2.0
# 365  yes         no     NaN    yes       no       no     3.0       3.0    4.0
# 383   no         no     NaN    yes       no       no     4.0       3.0    2.0
#
#      health  absences      score
# 22      5.0       2.0  80.000000
# 32      5.0       0.0  80.000000
# 85      5.0       6.0  40.000000
# 88      NaN      12.0  50.000000
# 152     3.0       8.0  50.000000
# 212     4.0       0.0  70.000000
# 249     5.0       0.0  75.000000
# 300     4.0      14.0  55.000000
# 332     4.0       0.0        NaN
# 336     5.0      12.0  65.000000
# 340     3.0       4.0  55.000000
# 341     2.0       0.0        NaN
# 350     2.0       8.0  52.027778
# 359     4.0       0.0  80.000000
# 365     3.0       4.0  50.000000
# 383     5.0       0.0        NaN

# %%
stud_math.loc[(stud_math.nursery.isnull() == True) & (
    stud_math.Fjob == 'at_home'), 'nursery'] = 'no'
stud_math.loc[(stud_math.nursery.isnull() == True) & (
    stud_math.Mjob == 'at_home'), 'nursery'] = 'no'
pd.DataFrame(stud_math.nursery.value_counts())
# Out:
#      nursery
# yes      277
# no        75

# %%
# Проверяем колонку higher
stud_math.loc[:, ['higher']].info()
pd.DataFrame(stud_math.higher.value_counts())
# есть 19 пустых значений. Если ученик планирует поступать, то высока вероятность, что он будет брать доп.занятия
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   higher  347 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      higher
# yes     332
# no       15

# %%
stud_math.loc[(stud_math.higher.isnull() == True) & (
    stud_math.paid == 'yes'), 'higher'] = 'yes'
stud_math.loc[(stud_math.higher.isnull() == True) & (
    stud_math.activities == 'yes'), 'higher'] = 'yes'
pd.DataFrame(stud_math.higher.value_counts())
# Out:
#      higher
# yes     343
# no       15

# %%
# Проверяем колонку internet
stud_math.loc[:, ['internet']].info()
pd.DataFrame(stud_math.internet.value_counts())
# есть 34 пустых значения, но нет основательных предположений, чтобы это изменить
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   internet  333 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      internet
# yes       278
# no         55

# %%
# Проверяем колонку romantic
stud_math.loc[:, ['romantic']].info()
pd.DataFrame(stud_math.romantic.value_counts())
# есть 31 пустое значение, но нет основательных предположений, чтобы это изменить
# есть предположение, что дети из неполных семей более склонны заводить отношения в раннем возрасте, но оно не достаточно основательное
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   romantic  335 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB
#      romantic
# no        225
# yes       110

# %% [markdown]
# # Корреляционный анализ¶

# %%
sns.heatmap(stud_math.corr())

# %%
stud_math.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.191169 -0.167174    0.094453   0.018086  0.157916
# Medu       -0.191169  1.000000  0.607656   -0.191069   0.081887 -0.258348
# Fedu       -0.167174  0.607656  1.000000   -0.165856   0.016026 -0.272640
# traveltime  0.094453 -0.191069 -0.165856    1.000000  -0.092257  0.093272
# studytime   0.018086  0.081887  0.016026   -0.092257   1.000000 -0.164916
# failures    0.157916 -0.258348 -0.272640    0.093272  -0.164916  1.000000
# famrel      0.050368 -0.023955 -0.031061   -0.023360   0.033981 -0.003562
# freetime    0.046351  0.027749 -0.005184   -0.008867  -0.133717  0.092049
# goout       0.123607  0.035605  0.042336    0.039342  -0.029000  0.071001
# health     -0.050944 -0.044416  0.027131   -0.014465  -0.097056  0.106751
# absences    0.129016  0.066703  0.000197   -0.048267  -0.070781  0.059555
# score      -0.125024  0.200250  0.132403   -0.072355   0.140926 -0.270152
#
#               famrel  freetime     goout    health  absences     score
# age         0.050368  0.046351  0.123607 -0.050944  0.129016 -0.125024
# Medu       -0.023955  0.027749  0.035605 -0.044416  0.066703  0.200250
# Fedu       -0.031061 -0.005184  0.042336  0.027131  0.000197  0.132403
# traveltime -0.023360 -0.008867  0.039342 -0.014465 -0.048267 -0.072355
# studytime   0.033981 -0.133717 -0.029000 -0.097056 -0.070781  0.140926
# failures   -0.003562  0.092049  0.071001  0.106751  0.059555 -0.270152
# famrel      1.000000  0.171281  0.087142  0.090672 -0.099445  0.069735
# freetime    0.171281  1.000000  0.294492  0.045139  0.083875 -0.002145
# goout       0.087142  0.294492  1.000000  0.004741  0.092347 -0.180029
# health      0.090672  0.045139  0.004741  1.000000 -0.005136 -0.070326
# absences   -0.099445  0.083875  0.092347 -0.005136  1.000000 -0.235060
# score       0.069735 -0.002145 -0.180029 -0.070326 -0.235060  1.000000

# %% [raw]
# Слабая корреляция числовых признаков. Наблюдается небольшая взаимосвязь параметра score с параметром Medu,Fedu,failures,goout,absences

# %%
for col in ['school', 'sex', 'address', 'famsize', 'Pstatus',
            'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
            'higher', 'internet', 'romantic', 'famrel', 'goout']:
    get_boxplot2(col)

# %% [raw]
# Судя по боксплотам:
# Учащиеся школы GP в целом показали лучшие результаты на экзамене по математике, средний балл выше, чем в школе MS, максимальный балл выше.Я бы отобрала этот критерий для дальнейшей модели.
#
# Мальчики показали более высокий результат, чем девочки, но пол слабо влияет на итоговую оценку.
#
# Ученики городских школ показали более высокие результаты, медианный результат тоже выше у учеников проживающих в сельской местности. Я бы отобрала этот критерий для дальнейшей модели.
#
# Размер семьи  слабо влияет на итоговую оценку.
#
# Ученики из неполных семей продемонстрировали более высокие результаты за экзамен, но этот критерий слабо влияет на итоговую оценку
#
# В среднем, результат экзамена по математике будет выше, если мама ребенка рботает в здравоохранении. Я бы отобрала этот критерий для дальнейшей модели.
#
# В среднем, результат экзамена по математике будет выше, если отец ребенка рботает в учителем. Я бы отобрала этот критерий для дальнейшей модели.
#
# В среднем, результат экзамена по математике будет выше, если при выборе школы родители основывались на репутации школы. Слабо влияет на оценку.
#
# В среднем, результат экзамена по математике будет выше, если опекуном ребенка является мама или папа. Слабо влияет на оценку.
#
# Дополнительная образовательная поддержка бесполезна, даже ухудшает ситуацию (странно конечно).Я бы отобрала этот критерий для дальнейшей модели.
#
# Семейная образовательная поддержка также почти бесполезна.
#
# Дополнительные платные занятия по математике бесполезны.
#
# Дополнительные внеучебные занятия положительно сказываются на оценке за экзамен.Но зависимость слабая.
#
# Посещение детского сада мало влияет на результат экзамена.
#
# Желание получить высшее образование положительно сказывается на оценке за экзамен. Я бы отобрала этот критерий для дальнейшей модели.
#
# Наличие интернета положительно сказывается на оценке за экзамен.Я бы отобрала этот критерий для дальнейшей модели.
#
# Наличие романтических отношений скорее негативно влияет на результаты экзмена.Я бы отобрала этот критерий для дальнейшей модели.
#
# В целом, в семьях с плохими взаимоотношениями самый высокий средний показатель оценки за экзамен. Я бы отобрала этот критерий для дальнейшей модели.

# %% [raw]
# Итого предварительно я бы отобрала параметры school,address, Mjob, Fjob, schoolsup, higher, internet, romantic,famrel

# %%
for col in [
        'school',
        'sex',
        'address',
        'famsize',
        'Pstatus',
        'Medu',
        'Fedu',
        'Mjob',
        'Fjob',
        'reason',
        'guardian',
        'traveltime',
        'studytime',
        'failures',
        'schoolsup',
        'famsup',
        'paid',
        'activities',
        'nursery',
        'higher',
        'internet',
        'romantic',
        'famrel',
        'freetime',
        'goout',
        'health',
]:
    get_stat_dif(col)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Users\Admin\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Users\Admin\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3584: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Выводы

# %% [raw]
# Для модели отбираем следующие параметры: sex, address, Medu, Mjob, studytime, failures, schoolsup, goout

# %% [raw]
# Качество данных:
# В данных наблюдается много пустых значений, только 3 столбца из 29 были заполнены полностью. Столбец stufdytime,granular выбросила
# сразу, поскольку он полностью коррелировался с stufdytime.
#
# С пропущенными значениями работала по-разному:
#     Заменяла:
#         в столбце fedu найдено невозможное значение 40, заменила на 4
#         в столбце famrel найдено невозможное значение -1, заменила на 1
#         В столбцах, касющихся здоровья, адреса, опекунства, образования родителей делала замены основываясь на логических выводах.
#         В целевой переменной все пропуски и нули заменила на среднее.
#     Оставляла:
#         Если невозможно было исправить.
#
# Корреляционный анализ ничего не показал, к сожалению, корреляцию обнаружить не удалось.
# Гепотезы, построенные на предварительном анализе номинативных переменных частично подтвердились.
